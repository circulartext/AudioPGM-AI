# %% [markdown]
# # Getting Started with Qiskit
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ionq-samples/getting-started/blob/main/qiskit.ipynb)
#
# [Qiskit](https://qiskit.org/) is an open-source quantum computing framework developed by IBM for building, simulating, and running quantum circuits on real and simulated quantum devices.

# %%
# %%capture

# First, we install the essential libraries to our current Python runtime.
# "%%capture" (above) captures and in this case, hides the output of this
# cell, so you can comment it out if you need help debugging this step.

# %pip install qiskit qiskit_ionq matplotlib pylatexenc

# %%
import os, qiskit_ionq
from getpass import getpass

# Before you begin, get your API key from https://cloud.ionq.com/settings/keys

# If your API key is stored as "IONQ_API_KEY" in your local environment, this
# should find it. Otherwise you'll be prompted to enter your API key manually.

api_key = os.getenv('IONQ_API_KEY') or getpass('Enter your IonQ API key: ')
provider = qiskit_ionq.IonQProvider(api_key)

# We need to specify a backend, which is where the circuit will be executed. In
# this case we're using the `ionq_simulator`, but if you have QPU access you
# can specify it here to run the job on a QPU directly.

backend = provider.get_backend('ionq_simulator')
# Out:
# Enter your IonQ API key: ··········
# /usr/local/lib/python3.12/dist-packages/qiskit_ionq/ionq_backend.py:127: IonQTranspileLevelWarning: Transpiler default optimization_level=2. IonQ (QIS) recommends 0-1 to avoid aggressive re-synthesis; use transpile(..., optimization_level=1).
#   warn_bad_transpile_level()

# %%
# Import Everything Needed
# ================================
from qiskit import QuantumCircuit, execute
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create a Simple 4-Qubit Circuit
# ================================
qc = QuantumCircuit(4, 4)

# Put first 2 qubits into superposition
qc.h(0)
qc.h(1)

# Add an entanglement chain
qc.cx(0, 2)
qc.cx(1, 3)

# Add some rotations
qc.rx(0.5, 2)
qc.ry(1.0, 3)

# Measure
qc.measure([0,1,2,3], [0,1,2,3])

# Show Circuit
print("Quantum Circuit:")
display(qc.draw(output='mpl'))

# Run Simulation
# ================================
sim = Aer.get_backend('qasm_simulator')
job = execute(qc, sim, shots=1024)
result = job.result()
counts = result.get_counts()

# Show Measurement Results
print("Measurement Results:")
display(plot_histogram(counts))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2368464689.py in <cell line: 0>()
#       1 # Import Everything Needed
#       2 # ================================
# ----> 3 from qiskit import QuantumCircuit, execute
#       4 from qiskit_aer import Aer
#       5 from qiskit.visualization import plot_histogram
#
# ImportError: cannot import name 'execute' from 'qiskit' (/usr/local/lib/python3.12/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Task
# Fix the `ImportError: cannot import name 'execute' from 'qiskit'` in cell `bd2c2829` to allow the Qiskit circuit code to execute successfully.

# %% [markdown]
# ## Re-execute Qiskit Circuit Code
#
# ### Subtask:
# Re-run the code in cell `bd2c2829` to observe the current execution status and identify any new or persistent errors.

# %% [markdown]
# **Reasoning**:
# The subtask explicitly asks to re-execute the code in cell `bd2c2829` to observe its current execution status and identify errors.

# %%
# Ensure Qiskit and Qiskit Aer are installed
# !pip install qiskit qiskit_aer

# Import Everything Needed
# ================================
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

qc = QuantumCircuit(8, 8)

# Operate on the first set of 4 qubits
qc.h(0)
qc.h(1)
qc.cx(0, 2)
qc.cx(1, 3)
qc.rx(0.01, 2)
qc.ry(0.01, 3)

# Operate on the second set of 4 qubits
qc.h(4)
qc.h(5)
qc.cx(4, 6)
qc.cx(5, 7)
qc.rx(0.01, 6)
qc.ry(0.01, 7)

# Measure all 8 qubits
qc.measure([0, 1, 2, 3, 4, 5, 6, 7], [0, 1, 2, 3, 4, 5, 6, 7])

# Run Simulation
# ================================
sim = Aer.get_backend('qasm_simulator')
job = sim.run(qc, shots=10000)
result = job.result()
counts = result.get_counts()

# Show Circuit
print("Quantum Circuit:")
display(qc.draw(output='mpl'))

# Show Measurement Resultsi
print("Measurement Results:")
display(plot_histogram(counts))
plt.show()
# Out:
# ...
# Quantum Circuit:
# Measurement Results:

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the code now runs successfully without errors.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# - The `ImportError: cannot import name 'execute' from 'qiskit'` that was previously reported has been resolved.
# - The Qiskit circuit code in cell `bd2c2829` now executes successfully without any errors.
# - The execution produced the expected quantum circuit visualization and a histogram of the measurement results.
#
# ### Insights or Next Steps
# - The fix for the `ImportError` was effective, and the Qiskit circuit simulation can now proceed as intended.
# - The project can continue with further analysis or development of the quantum circuit.
